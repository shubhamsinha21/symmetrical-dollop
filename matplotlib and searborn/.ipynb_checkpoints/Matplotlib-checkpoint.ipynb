# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basics

# %% [markdown]
# ## Subplots in matplotlib

# %% [markdown]
# ## Object oriented way

# %% [markdown]
# ## Types of plots

# %% [markdown]
# ## Saving plots

# %% [markdown]
# ## Working with images

# %% [markdown]
# **Optional Designing**
