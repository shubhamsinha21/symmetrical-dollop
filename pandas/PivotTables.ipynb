# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    583     78   John  January      Q1
# 1  2023-01-02       B   West    158     48   Mary  January      Q1
# 2  2023-01-03       C  North    838     18    Bob  January      Q1
# 3  2023-01-04       D  South    347     41  Alice  January      Q1
# 4  2023-01-05       A   East    938     66   John  January      Q1
# 5  2023-01-06       B   West    840     82   Mary  January      Q1
# 6  2023-01-07       C  North    969     88    Bob  January      Q1
# 7  2023-01-08       D  South    909     52  Alice  January      Q1
# 8  2023-01-09       A   East    967     53   John  January      Q1
# 9  2023-01-10       B   West    423     66   Mary  January      Q1
# 10 2023-01-11       C  North    964     21    Bob  January      Q1
# 11 2023-01-12       D  South    349     12  Alice  January      Q1
# 12 2023-01-13       A   East    586     24   John  January      Q1
# ...

# %%
pd.pivot_table(df, values="Sales", index="Region", columns="Product", aggfunc="max") # passing dataframe,
# Out:
# Product      A      B      C      D
# Region
# East     967.0    NaN    NaN    NaN
# North      NaN    NaN  969.0    NaN
# South      NaN    NaN    NaN  909.0
# West       NaN  889.0    NaN    NaN

# %%
pivot = pd.pivot_table(df, values=["Sales","Units"], 
                       index="Region", columns="Product", aggfunc="max")
# passing dataframe, values, 
# values must be numeric columns

# %%
pivot
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     967.0    NaN    NaN    NaN  78.0   NaN   NaN   NaN
# North      NaN    NaN  969.0    NaN   NaN   NaN  88.0   NaN
# South      NaN    NaN    NaN  909.0   NaN   NaN   NaN  52.0
# West       NaN  889.0    NaN    NaN   NaN  82.0   NaN   NaN

# %%
#

# %% [markdown]
# ## Cross tabs
